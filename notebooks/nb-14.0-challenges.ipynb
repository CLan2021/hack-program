# %% [markdown]
# ## Python challenges
#
# This notebook includes a series of challenges to test your Python coding skills. If you get stuck, try googling for answers. If you don't understand *why* a particular answer works, try searching for the answer to that question. Revisit old tutorials from this class as needed, and finally, turn to the course chatroom for help. Best of luck.

# %%
# required software
# conda install numpy pandas toyplot requests -c conda-forge

# %%
import requests
import numpy as np
import pandas as pd
import toyplot

# %% [markdown]
# ### Challenge 1:
# Execute the code cell below to see an example of how it works.
# Use markdown in the cell after the code-block to describe the function `random_words_api`. Try to be descriptive about what each step of code in this function does, and why it works.

# %%
def random_words_api(nwords=10):
    "no docstring"
    URL = "https://random-word-api.herokuapp.com/word"
    response = requests.get(url=URL, params={"number": nwords})
    return response.json()

# demonstration
random_words_api(5)
# Out:
# ['enucleated', 'ferreous', 'janissaries', 'farolitos', 'subcavity']

# %% [markdown]
# **Description:** This function "random_words_api" queries the random word api database hosted at the given URL and returns a default of 10 words if not specified. Then a "response" variable is created, containing the get() method which sends a GET request to the specified url as well as the parameter formatted as a dictionary that specified the number of words. Finally, the results are shown by using the json() method where it takes a Response stream and reads it to completion.

# %% [markdown]
# ### Challenge 2:
# Use the `random_words_api` function to get 50 random words and store the result as a variable. Write a function that takes the list of words as input and returns a dictionary with the longest word as the key and the length of the longest word as a value. If there is a tie in the length of words then have it return additional words as keys with their lengths as values.

# %%
rando = random_words_api(50)

def longest_word(word):
    sort = {}
    for i in word:
        if len(i) == len(max(rando, key=len)):
            sort[i] = len(max(rando, key=len))
    return sort

print(longest_word(rando))
# Out:
# {'chronologically': 15}

# %% [markdown]
# ### Challenge 3:
# Write a function to take the list of words as input and trim all words to be at most 5 characters in length, and return as a list.

# %%
def trim(rando):
    trimmed = []
    for i in rando:
        trimmed.append(i[:5])
    return trimmed

print(trim(rando))
# Out:
# ['wildf', 'goadl', 'glime', 'tamba', 'cloth', 'trepa', 'incor', 'paphi', 'panad', 'machi', 'stran', 'holst', 'homog', 'nonex', 'flatt', 'crani', 'slipf', 'folkt', 'semia', 'osteo', 'chuck', 'overs', 'silen', 'brain', 'menar', 'cloud', 'match', 'biath', 'subsh', 'linco', 'minib', 'bival', 'evict', 'gulli', 'gouge', 'impos', 'bacon', 'water', 'utter', 'there', 'hepto', 'trier', 'defor', 'phena', 'provi', 'chron', 'refre', 'trito', 'broca', 'pitil']

# %% [markdown]
# ### Challenge 4:
# Write a function to take a list of words as input and to count the occurrence of all letters in every word and return as a dictionary mapping letters to integers., e.g., {'a': 10, 'b': 3, 'c': 5, ...}.

# %%
def count_letters(rando):
    counts = {}
    for i in rando:
        for letter in i:
            keys = counts.keys()
            if letter in keys:
                counts[letter] += 1
            else:
                counts[letter] = 1
    sort_dict = {}
    for key in sorted(counts.keys()):
        sort_dict.update({key: counts[key]})
    return sort_dict

print(count_letters(rando))
# Out:
# {'a': 33, 'b': 11, 'c': 20, 'd': 9, 'e': 48, 'f': 6, 'g': 15, 'h': 19, 'i': 45, 'k': 6, 'l': 34, 'm': 13, 'n': 37, 'o': 33, 'p': 13, 'r': 30, 's': 39, 't': 25, 'u': 8, 'v': 4, 'w': 4, 'x': 1, 'y': 7, 'z': 2}

# %% [markdown]
# ### Challenge 5:
# Use [toyplot](https://toyplot.readthedocs.io/en/stable/tutorial.html) to create a barplot of the occurrences of each letter in your dictionary from the previous challenge. This will represent a histogram of the letters. Play with the size and color of the figure to try to make it look nice.

# %%
alist = count_letters(rando)
mylist = list(alist.values())

# %%
string = "   ".join(list(alist.keys()))
x = list(range(len(mylist)))
y = mylist

canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.cartesian(label="letter occurrence", xlabel=string, ylabel="counts")
mark = axes.bars(x,y, color = "pink")
# Out:
# <div class="toyplot" id="tc664e87e5151474dbca9cd4cdc65d3a6" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="td35d377a30a642519637c8c40bc3eacd" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta9b3d820a9554bc79eab6433e2f01977"><clipPath id="t1d0fa3bd9a134dfeb226d9eb11775d38"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t1d0fa3bd9a134dfeb226d9eb11775d38)"><g class="toyplot-mark-BarMagnitudes" id="tce64a921327040d1ab4bcd86be0f5ed7" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="132.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.66666666666667" x="50.0" y="117.99999999999999"></rect><rect class="toyplot-Datum" height="44.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666657" x="66.66666666666667" y="206.0"></rect><rect class="toyplot-Datum" height="80.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.66666666666667" x="83.33333333333333" y="170.0"></rect><rect class="toyplot-Datum" height="35.99999999999997" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.66666666666667" x="100.0" y="214.00000000000003"></rect><rect class="toyplot-Datum" height="192.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666643" x="116.66666666666667" y="58.00000000000001"></rect><rect class="toyplot-Datum" height="24.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666686" x="133.33333333333331" y="226.0"></rect><rect class="toyplot-Datum" height="60.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666657" x="150.0" y="190.0"></rect><rect class="toyplot-Datum" height="76.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666686" x="166.66666666666666" y="174.0"></rect><rect class="toyplot-Datum" height="180.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666657" x="183.33333333333334" y="70.0"></rect><rect class="toyplot-Datum" height="24.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666657" x="200.0" y="226.0"></rect><rect class="toyplot-Datum" height="136.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666686" x="216.66666666666666" y="113.99999999999999"></rect><rect class="toyplot-Datum" height="52.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.666666666666657" x="233.33333333333334" y="198.0"></rect><rect class="toyplot-Datum" height="148.0" style="fill:rgb(100%,75.3%,79.6%);fill-opacity:1.0;opac ...

# %% [markdown]
# ### Challenge 6:
# Using numpy create a new variable called `arr` with 1000 random samples from a normal distribution. Use the numpy `.histogram` function to bin these values into 20 bins, and then plot the histogram using a barplot from toyplot. Color the bars of the histogram orange.

# %%
arr = np.random.normal(size=1000)
hist = np.histogram(arr, bins=20)

canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.cartesian()
bars = axes.bars(hist, color = "orange")
# Out:
# <div class="toyplot" id="t61d62fa2919e43a8a4793dc1abd634e0" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t34cf663de377492abe3717ef171e41fb" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t583d7c5efe83430e9b5ee92895e91300"><clipPath id="t15292be72ec441bb95852f5d7628d813"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t15292be72ec441bb95852f5d7628d813)"><g class="toyplot-mark-BarMagnitudes" id="ta74f5183b223422d86840e31b5cc22a6" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="2.666666666666657" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947904" x="82.48036080088654" y="247.33333333333334"></rect><rect class="toyplot-Datum" height="4.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947875" x="99.19115077283445" y="246.0"></rect><rect class="toyplot-Datum" height="5.333333333333314" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947904" x="115.90194074478232" y="244.66666666666669"></rect><rect class="toyplot-Datum" height="10.666666666666686" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947918" x="132.61273071673023" y="239.33333333333331"></rect><rect class="toyplot-Datum" height="38.666666666666686" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.71078997194786" x="149.32352068867814" y="211.33333333333331"></rect><rect class="toyplot-Datum" height="48.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947918" x="166.034310660626" y="202.0"></rect><rect class="toyplot-Datum" height="93.33333333333331" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.71078997194789" x="182.74510063257392" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="120.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947918" x="199.4558906045218" y="130.0"></rect><rect class="toyplot-Datum" height="152.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.71078997194786" x="216.16668057646973" y="98.0"></rect><rect class="toyplot-Datum" height="174.66666666666666" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.71078997194789" x="232.8774705484176" y="75.33333333333334"></rect><rect class="toyplot-Datum" height="176.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947946" x="249.58826052036548" y="74.0"></rect><rect class="toyplot-Datum" height="168.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="16.710789971947918" x="266.2990504923134" y="82.0"></r ...

# %% [markdown]
# ### Challenge 7:
# Write a `while` statement to continue running code in a loop until a condition is met, and then call `break` to end the loop. Inside of the loop, randomly draw a single value from a uniform distribution between 0 and 100. If the value is less than 25 and greater than 22 then break the loop, otherwise, continue the loop until a value meeting this condition is sampled. Use a variable to keep track of how many iterations of the loop are run, and print this value after calling `break`.

# %%
iteration = 0
while np.random.uniform(0, 100, 1):
    iteration += 1
    if 22 < np.random.uniform(0, 100, 1) < 25:
        break
print("Number of iterations ran = " + str(iteration))
# Out:
# Number of iterations ran = 6

# %% [markdown]
# ### Challenge 8:
# Use pandas to load a CSV file from https://eaton-lab.org/data/iris-data-dirty.csv and save as a dataframe. Add custom names to the columns in the dataframe, based on the type of values in them (e.g., numeric versus strings). You can come up with any column names you want for these.

# %%
df = pd.read_csv("https://eaton-lab.org/data/iris-data-dirty.csv", header=None)
df.columns = ['trait1','trait2','trait3','trait4','species']
df.head()
# Out:
#    trait1  trait2  trait3  trait4      species
# 0     5.1     3.5     1.4     0.2  Iris-setosa
# 1     4.9     3.0     1.4     0.2  Iris-setosa
# 2     4.7     3.2     1.3     0.2  Iris-setosa
# 3     4.6     3.1     1.5     0.2  Iris-setosa
# 4     5.0     3.6     1.4     0.2  Iris-setosa

# %% [markdown]
# ### Challenge 9:
# Calculate the mean value of the data in the left-most column for all data where the right-most column matches the value "Iris-setosa".

# %%
sub = df.loc[df["species"] == "Iris-setosa"]
sub["trait1"].mean()
# Out:
# 5.010204081632653

# %% [markdown]
# ### Challenge 10:
# Create a copy of your iris data dataframe and name it `df2`. Sort the rows of this dataframe based on the values in the first (leftmost) column so that the lowest values are first, and the highest values at the bottom. After sorting, reset the index of the dataframe so that the index is once again ordered. Once you get this to work, try to rewrite it in a simpler form by chaining multiple function calls together to accomplish the goal in one line, by calling code that looks a bit like this, but with the correct function calls: `df.function().function().function()`

# %%
test = df.copy()
test = df2.sort_values(by=['trait1'])
test = df2.reset_index(drop=True)
test
# Out:
#      trait1  trait2  trait3  trait4         species
# 0       4.3     3.0     1.1     0.1     Iris-setosa
# 1       4.4     3.2     1.3     0.2     Iris-setosa
# 2       4.4     3.0     1.3     0.2     Iris-setosa
# 3       4.4     2.9     1.4     0.2     Iris-setosa
# 4       4.5     2.3     1.3     0.3     Iris-setosa
# ..      ...     ...     ...     ...             ...
# 145     7.7     2.8     6.7     2.0  Iris-virginica
# 146     7.7     2.6     6.9     2.3  Iris-virginica
# 147     7.7     3.8     6.7     2.2  Iris-virginica
# 148     7.7     3.0     6.1     2.3  Iris-virginica
# 149     7.9     3.8     6.4     2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# chaining multiple function
df2 = df.copy().sort_values(by=['trait1']).reset_index(drop=True)
df2
# Out:
#      trait1  trait2  trait3  trait4         species
# 0       4.3     3.0     1.1     0.1     Iris-setosa
# 1       4.4     3.2     1.3     0.2     Iris-setosa
# 2       4.4     3.0     1.3     0.2     Iris-setosa
# 3       4.4     2.9     1.4     0.2     Iris-setosa
# 4       4.5     2.3     1.3     0.3     Iris-setosa
# ..      ...     ...     ...     ...             ...
# 145     7.7     2.8     6.7     2.0  Iris-virginica
# 146     7.7     2.6     6.9     2.3  Iris-virginica
# 147     7.7     3.8     6.7     2.2  Iris-virginica
# 148     7.7     3.0     6.1     2.3  Iris-virginica
# 149     7.9     3.8     6.4     2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Challenge 11:
# Write a function that uses string formatting (curly braces) to create a [mad lib](https://en.wikipedia.org/wiki/Mad_Libs) containing at least 4 words that will be filled in. The returned object of your function should be a string where the missing words are filled by randomly sampled words from the `random_words_api()` function. The sentence or paragraph of your mad lib can be anything you wish, be creative.

# %%
def mad_lib():
    URL = "https://random-word-api.herokuapp.com/word"
    response = requests.get(url=URL, params={"number": 4})
    print("""
    Then came the night of the first falling {}. 
    It was seen early in the {}, a line of flame high in the atmosphere. 
    Hundreds must have seen {} and taken it for an ordinary falling star. 
    It seemed that it fell to earth about one hundred miles east of {}."""
    .format(response.json()[0], response.json()[1], response.json()[2], response.json()[3])
         )

mad_lib()
# Out:
#     Then came the night of the first falling mistranscribing.
#     It was seen early in the amalgamated, a line of flame high in the atmosphere.
#     Hundreds must have seen sheepcots and taken it for an ordinary falling star.
#     It seemed that it fell to earth about one hundred miles east of cullet.

# %% [markdown]
# <div class="alert alert-success">
# After completing all challenges in this notebook, save and download the .ipynb file to your computer. Move the file to your hack-program repo and put it in a folder called notebooks. Add/stage this file and folder and commit the change, and push to GitHub. The assignment is due by end of day on 3/7/2021.
# </div>
